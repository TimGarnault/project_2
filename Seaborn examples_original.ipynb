# %%
print('Hello World!')
# Out:
# Hello World!

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Distribution Plots
#
#
# Let's discuss some plots that allow us to visualize the distribution of a data set. These plots are:
#
# * displot
# * jointplot
# * pairplot
# * rugplot
# * kdeplot

# %% [markdown]
# The distplot shows the distribution of a univariate set of observations.

# %%
# sns.set_theme(style="whitegrid")
# sns.set_theme(style="ticks")

# %%
# The distplot shows the distribution of a univariate set of observations.
# get a distribution plot to show the distribution of a univariate set
#sns.displot(tips['total_bill'])
sns.displot(data = tips, x='total_bill')

# %%
# To remove the kde layer and just have the histogram use:
# get a distribution plot to show the distribution of a univariate set
sns.displot(tips['total_bill'])

# %%
# get a distribution plot to show the distribution of a univariate set
sns.displot(tips['total_bill'], kde = False, bins= 80)

# %%
# jointplot: essentially combine two different distribution plots. two variables.
sns.jointplot(data=tips, x= 'total_bill' , y= 'tip')

# %% [markdown]
#  jointplot() allows you to basically match up two distplots for bivariate data. With your choice of what **kind** parameter to compare with:
# * “scatter”
# * “reg”
# * “resid”
# * “kde”
# * “hex”

# %%
# jointplot: essentially combine two different distribution plots. two variables.
sns.jointplot(x= 'total_bill' , y= 'tip', data=tips, kind = 'hex' )

# %%
# jointplot: essentially combine two different distribution plots. two variables.
sns.jointplot(x= 'total_bill' , y= 'tip', data=tips, kind = 'reg' )

# %%
# jointplot: essentially combine two different distribution plots. two variables.
sns.jointplot(x= 'total_bill' , y= 'tip', data=tips, kind = 'kde' )

# %% [markdown]
# ## pairplot
#
# pairplot will plot pairwise relationships across an entire dataframe (for the numerical columns) and supports a color hue argument (for categorical columns).

# %%
# Pairplot to plot pairwise relationships across an entire data frame at least for the numerical columns.
# its joint plots for every single possible combination of the numerical columns in this data frame.
sns.pairplot(tips)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.pairplot(tips, hue = 'time')

# %%
sns.pairplot(tips, hue = 'sex', palette= 'coolwarm')

# %% [markdown]
# ## rugplot
#
# rugplots are actually a very simple concept, they just draw a dash mark for every point on a univariate distribution. They are the building block of a KDE plot:

# %%
# rugplot to draw a dash mark for every single point along the distribution line.
sns.rugplot(tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
#  build the this the KDE plot without any distribution of the bars.
sns.kdeplot(tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# # Categorical Data Plots
#
# Now let's discuss using seaborn to plot categorical data! There are a few main plot types for this:
#
# * factorplot
# * boxplot
# * violinplot
# * stripplot
# * swarmplot
# * barplot
# * countplot
#
# Let's go through examples of each!

# %% [markdown]
# ## barplot and countplot
#
# These very similar plots allow you to get aggregate data off a categorical feature in your data. **barplot** is a general plot that allows you to aggregate the categorical data based off some function, by default the mean:

# %%
# for categorical plots were mainly going to be concerned about seeing the distributions of a categorical column

# %%
# barplot will create a bar plots showing  the average or mean of the total bill.
sns.barplot( data= tips, x= 'time', y= 'total_bill')
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
import numpy as np

# %%
# You can change the estimator object to your own function, that converts a vector to a scalar:

# %%
# use an estimator to see what is the standard deviation of the total bill column per category
sns.barplot(x= 'sex', y= 'total_bill', data= tips, estimator= np.std)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ### countplot
#
# This is essentially the same as barplot except the estimator is explicitly counting the number of occurrences. Which is why we only pass the x value:

# %%
# count plots is essentially the same as a bar plot except the estimator
# is explicitly counting the number of occurrences. so, we only set the x value.
sns.countplot(x= 'sex', data = tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ## boxplot and violinplot
#
# boxplots and violinplots are used to shown the distribution of categorical data. A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable. The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.

# %%
# box plot shows the distribution of quantitative data in a way that facilitates comparisons between the variables.
sns.boxplot(x= 'day', y= 'total_bill', data = tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="day", y="total_bill", data=tips, hue = "day", palette="rainbow")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=tips,palette='rainbow',orient='h')
# Out:
# <Axes: >

# %%
# get a bit fancy
sns.boxplot(x= 'day', y= 'total_bill', data = tips, hue= 'smoker')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### violinplot
# A violin plot plays a similar role as a box and whisker plot. It shows the distribution of quantitative data across several levels of one (or more) categorical variables such that those distributions can be compared. Unlike a box plot, in which all of the plot components correspond to actual datapoints, the violin plot features a kernel density estimation of the underlying distribution.

# %%
# Now the violin plot unlike the box plot allows us to actually plot all the components that correspond
# to actual data points and it's essentially showing the kernel density estimation of the underlying distribution
sns.violinplot(x= 'day', y= 'total_bill', data = tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x= 'day', y= 'total_bill', data = tips, hue = 'sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day", y="total_bill", data=tips,hue='sex',palette='Set1')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# advanced visualisation
sns.violinplot(x= 'day', y= 'total_bill', data = tips, hue = 'sex', split = True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# bold text## stripplot and swarmplot
# The stripplot will draw a scatterplot where one variable is categorical. A strip plot can be drawn on its own, but it is also a good complement to a box or violin plot in cases where you want to show all observations along with some representation of the underlying distribution.
#
# The swarmplot is similar to stripplot(), but the points are adjusted (only along the categorical axis) so that they don’t overlap. This gives a better representation of the distribution of values, although it does not scale as well to large numbers of observations (both in terms of the ability to show all the points and in terms of the computation needed to arrange them).

# %%
#  the strip plot is going to draw a scatterplot where one variable is categorical.
sns.stripplot(x= 'day', y= 'total_bill', data = tips, jitter= False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# So the normal stript plot if it had a bunch of points stacked on top of each other its hard to tell.
# so to see the density a little better

sns.stripplot(x= 'day', y= 'total_bill', data = tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x= 'day', y= 'total_bill', data = tips, hue= 'sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x= 'day', y= 'total_bill', data = tips, hue= 'sex', dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Combining Categorical Plots

# %%
# swarm plot is essentially a combination of a strip plot and a violent plot.
# It shows the same distribution except it's actually showing all the points themselves.
# in general probably stay away from just showing swarm plots since most people probably haven't encountered them before.

sns.swarmplot(x= 'day', y= 'total_bill', data = tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# not obvious? okay here we go! :)
#This is probably not useful for presentation but maybe just for exploratory data analysis
sns.violinplot(x= 'day', y= 'total_bill', data = tips)
sns.swarmplot(x= 'day', y= 'total_bill', data = tips, color= 'black')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## factorplot
#
# factorplot is the most general form of a categorical plot. It can take in a **kind** parameter to adjust the plot type:

# %%
sns.violinplot(x="tip", y="day", data=tips,palette='rainbow')
sns.swarmplot(x="tip", y="day", data=tips,color='black',size=3)
# Out:
# <ipython-input-14-cdfb3e236ec6>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="tip", y="day", data=tips,palette='rainbow')
# <Axes: xlabel='tip', ylabel='day'>

# %%
sns.factorplot(x= 'day' , y= 'total_bill', data = tips, kind= 'bar' )

# %% [markdown]
# # Regression Plots
#
# Seaborn has many built-in capabilities for regression plots, however we won't really discuss regression until the machine learning section of the course, so we will only cover the **lmplot()** function for now.
#
# **lmplot** allows you to display linear models, but it also conveniently allows you to split up those plots based off of features, as well as coloring the hue based off of features.
#
# Let's explore how this works:

# %%
## lmplot()

# %%
sns.lmplot(x= 'total_bill', y= 'tip', data = tips)

# %% [markdown]
# ### Working with Markers
#
# lmplot kwargs get passed through to **regplot** which is a more general form of lmplot(). regplot has a scatter_kws parameter that gets passed to plt.scatter. So you want to set the s parameter in that dictionary, which corresponds (a bit confusingly) to the squared markersize. In other words you end up passing a dictionary with the base matplotlib arguments, in this case, s for size of a scatter plot. In general, you probably won't remember this off the top of your head, but instead reference the documentation.

# %%
sns.lmplot(x= 'total_bill', y= 'tip', data = tips, hue= 'sex')

# %%
# http://matplotlib.org/api/markers_api.html
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='Set1',
           markers=['*','v'],scatter_kws={'s':300})

# %% [markdown]
# ## Using a Grid
#
# We can add more variable separation through columns and rows with the use of a grid. Just indicate this with the col or row arguments:

# %%
sns.lmplot(x= 'total_bill', y= 'tip', data = tips, hue= 'sex', markers= ['o', 'v'])

# %%
sns.lmplot(x= 'total_bill', y= 'tip', data = tips, col = 'sex')

# %%
sns.lmplot(x= 'total_bill', y= 'tip', data = tips, col = 'sex', row = 'time')

# %%
sns.lmplot(x= 'total_bill', y= 'tip', data = tips, col = 'day', hue= 'sex')

# %% [markdown]
# ## Aspect and Size
#
# Seaborn figures can have their size and aspect ratio adjusted with the **size** and **aspect** parameters:

# %%
sns.lmplot(x= 'total_bill', y= 'tip', data = tips, col = 'day', hue= 'sex', aspect= 0.6, size= 12)

# %%
sns.lmplot(x= 'total_bill', y= 'tip', data = tips, col = 'day', hue= 'sex', aspect= 0.6, size= 8)

# %% [markdown]
# You're probably wondering how to change the font size or control the aesthetics even more, check out the Style and Color Lecture and Notebook for more info on that!

# %% [markdown]
# ## Matrix Plots

# %% [markdown]
# # Matrix Plots
#
# Matrix plots allow you to plot data as color-encoded matrices and can also be used to indicate clusters within the data (later in the machine learning section we will learn how to formally cluster data).
#
# Let's begin by exploring seaborn's heatmap and clutermap:

# %%
# import another dataset which is FLIGHT data set
flights = sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %% [markdown]
# ## Heatmap
#
# In order for a heatmap to work properly, your data should already be in a matrix form, the sns.heatmap function basically just colors it in for you. For example:

# %%
num_tips = tips.select_dtypes(include='number')

# %%
# "Heat Maps" which is our primary way of showing some sort of matrix form
# do a correlation data first, save it in a variable to use it in the heat map
tc = num_tips.corr()

# %%
tc
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tc, vmin=-1) #the heat map colors in those values based on some sort of gradient scale.
# if you have a very large correlation data frame or some other matrix form data you can
# easily tell what the numbers are what the values are relative to each other using a heat map.
# And that's the main primary use for a matrix plot.
# Out:
# <Axes: >

# %%
sns.heatmap(tc, annot= True, vmin=-1) # ANNOT arguments equals true and they will annotate the actual numerical values.
# so You don't just go off of color but you can also go off of the actual value here.
# Out:
# <Axes: >

# %%
sns.heatmap(tc, annot= True, cmap='coolwarm', vmin=-1) #
# Out:
# <Axes: >

# %% [markdown]
# Or for the flights data:

# %%
fp = flights.pivot_table(index = 'month', columns= 'year', values='passengers' ) # now I have my data in a matrix form
# Out:
# <ipython-input-33-b1f51c3503fb>:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   fp = flights.pivot_table(index = 'month', columns= 'year', values='passengers' ) # now I have my data in a matrix form

# %%
# use a heat map to quiclly visualize this data
sns.heatmap(fp, cmap='coolwarm', linecolor= 'white', linewidths=1) #use some arrguments, there are a lot of costumisation we can get here
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# ## clustermap
#
# The clustermap uses hierarchal clustering to produce a clustered version of the heatmap. For example:

# %%
sns.clustermap(fp)

# %% [markdown]
# Notice now how the years and months are no longer in order, instead they are grouped by similarity in value (passenger count). That means we can begin to infer things from this plot, such as August and July being similar (makes sense, since they are both summer travel months)

# %%
sns.clustermap(fp, cmap= 'coolwarm')

# %%
# normalise the scale may be ? pass an argument
sns.clustermap(fp, cmap= 'coolwarm', standard_scale=1 )

# %%
"""I encourage you to go ahead and explore the documentation for these maps, or any other you're intersted in
 but you may want to wait until we actually get to machine learning
clustering algorithms so we can better understand what's actually going on with the mathematics behind
these methods.

a heat map will display things in the order you put them in
a cluster map will cluster things in an order, so that similar groups are close to each other."""

# %% [markdown]
# ## Grids

# %% [markdown]
# # Grids
#
# Grids are general types of plots that allow you to map plot types to rows and columns of a grid, this helps you create similar plots separated by features.

# %%
# upload the iris data set. iris dataset is a pretty famous set.
# It's basically just measurements of a bunch of different flowers or irises.
# And the last cone here on species, has three distinct types of values.
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
# simple pairplot which like automated joint plot for the entire data set
sns.pairplot(iris)

# %% [markdown]
# ## PairGrid
#
# Pairgrid is a subplot grid for plotting pairwise relationships in a dataset.

# %%
# pair grid, give the ability to customize the pair plot a lot more control over the actual plots
# call PairGrid instead of pairplot: does a lot of stuff automatically , PairGrid: You have to do a little more but it gives you a lot more control.
sns.PairGrid(iris)

# %%
# Then you map to the grid
g = sns.PairGrid(iris)
g.map(plt.scatter)

# %%
# Map to upper,lower, and diagonal

# set this pairGrid equal to a variable then go off of this variable you can map what type the plots you want
g = sns.PairGrid(iris)
g.map_diag(sns.distplot)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)

# %% [markdown]
# ## pairplot
#
# pairplot is a simpler version of PairGrid (you'll use quite often)

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris,hue='species',palette='rainbow')

# %% [markdown]
# ## Facet Grid
#
# FacetGrid is the general way to create grids of plots based off of a feature:

# %%
# Fasset Grid
tips = sns.load_dataset('tips')
tips.head()

# %%
# a very simple example of the Facet grid by just showing the grid
fg = sns.FacetGrid(data = tips, col = 'time', row= 'smoker' )

# %%
fg = sns.FacetGrid(data =tips, col="time",  row="smoker")
fg = fg.map(plt.hist , "total_bill")

# %%
# Now I have an empty grid that can begin to actually map what types to this group.
fg.map(sns.distplot, 'total_bill')

#  so the x axis represents total bill but there's four separate
# plots and they're actually labeled for us so yes and no and smokers are the rows,
# and the actual time of lunch versus dinner is specified by the column.
# So the left column is lunch the right column is dinner the top row is smokers and the bottom row is

# %%
# this not belongs to the plot above
#  so the x axis represents total bill but there's four separate
# plots and they're actually labeled for us so yes and no and smokers are the rows,
# and the actual time of lunch versus dinner is specified by the column.
# So the left column is lunch the right column is dinner the top row is smokers and the bottom row is non-smokers
# and the distribution plots for the total bill column.
# So there's essentially kind of three arguments at play here.
# The rows and column names are what variables you want to separate by for your Facet grid.
# And then when you're mapping you're going to add in one more argument which actually want to map for display.

# %%
# If you're trying to map a plot type that needs more than one argument.
# we can use the scattger plot, ex total bill VS tip
# not: distplot is taking one arguments, on the other hand scatter plot must be provided by 2 arguments

fg = sns.FacetGrid(data = tips, col = 'time', row= 'smoker' )
fg.map(plt.scatter, 'total_bill', 'tip')

# %%
fg = sns.FacetGrid(tips, col="time",  row="smoker",hue='sex')
# Notice hwo the arguments come after plt.scatter call
fg = fg.map(plt.scatter, "total_bill", "tip").add_legend()

# %% [markdown]
# Seaborn is basic plotting capabilities are actually quite enough for us throughout the course
#
# The sort of grid functions are only here for you if you want to customize your plots even further.

# %% [markdown]
# ## JointGrid
#
# JointGrid is the general version for jointplot() type grids, for a quick example:

# %%
fg = sns.JointGrid(x="total_bill", y="tip", data=tips)

# %%
fg = sns.JointGrid(x="total_bill", y="tip", data=tips)
fg = fg.plot(sns.regplot, sns.distplot)

# %% [markdown]
# Reference the documentation as necessary for grid types, but most of the time you'll just use the easier plots discussed earlier.

# %% [markdown]
# ## Regression Plots

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# LM plot allows you to display linear models with Seaborn;  has many built in capabilities for reggression and plots. which essential for the ML
# use LM plot to make a very simple linear model plot you just call LMplot and what feature you want on the x axis versus the y axis
sns.lmplot(data= tips, x= 'total_bill', y= 'tip')

# %%
# can also specify Hue for some seperation based off categorical feature, for instance SEX,
# and get two scatter plots and 2 linear fit on the top
sns.lmplot(data= tips, x= 'total_bill', y= 'tip', hue = 'sex')

# %%
#  note here: can actually begin to pass in, the MAtplotlib style parameters such as the markers; which come from  Matplotlib marker symbols.
sns.lmplot(data= tips, x= 'total_bill', y= 'tip', hue = 'sex', markers=['o', 'v'])

# %%
plt.scatter()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-1516a20b26b1> in <cell line: 1>()
# ----> 1 plt.scatter()
#
# TypeError: scatter() missing 2 required positional arguments: 'x' and 'y'

# %%
# not large enough to see?  go ahead and begin to add in what's known
# as a scatter_kws parameter and basically what that means is I can actually passing matplotlib
# parameters even more directly into the Plt.scatter call.
# So what seaborn is doing with this sns.lmplot is actually calling matplotlib very much under the hood.
# And if you want to effect matplotlib directly from seaborn: but its kind of a case by case basis so you have to reference the documentation as necessary.
# for ex. here you gonna pass a dictionary and change the size of these markers like 'S': 100
# So this is actually just a call to matplotlib and what's going on underneath the hood of Seaborn.
# In other words you're just passing any dictionary with base matplotlib arguments and in this case it S as for size of a scatterplot
# in general you probably won't remember this kind of thing off the top of your head but is that reference the documentation.
# And you probably won't be customizing to this degree that often with Seaborn.
# You'll go ahead and customize your data first before doing this sort of action.

sns.lmplot(data= tips, x= 'total_bill', y= 'tip', hue = 'sex', markers=['o', 'v'], scatter_kws= {'s' : 100}  )

# %%
"""Let's go ahead and show you a couple of more options here.

In case you don't want to mess around with marker sizing you can actually use a grid instead of separating

by Hue. so you can add more by saying sns.lmplot and

instead of specifying something like Hue equals sex which changes the color hue

you can actually start calling factor or grid plot's like saying col equal sex for columns.

And now you have to separate column plots here separated by the sex category.

So instead of separating it by color separated by columns and
you can continue this sort of logic on rows as well. """

sns.lmplot(data= tips, x= 'total_bill', y= 'tip', col = 'sex')

# %%
# So instead of separating it by color separated by columns and
# you can continue this sort of logic on rows as well.

"""this is essentially just doing the grid calls and the Fassett grid

calls that we learned about earlier in the grid.

But it's a little more automatic because we're just adding col and row to the LMplot call.

So it makes it a lot easier. """


sns.lmplot(data= tips, x= 'total_bill', y= 'tip', col = 'sex', row= 'time')

# %%
sns.lmplot(data= tips, x= 'total_bill', y= 'tip', col = 'day', hue= 'sex')

# %%
# have a problem with the siye and aspect?
sns.lmplot(data= tips, x= 'total_bill', y= 'tip', col = 'day', hue= 'sex', aspect = 0.6, size = 8)

# %% [markdown]
# ## Style and Color

# %% [markdown]
# # Style and Color
#
# We've shown a few times how to control figure aesthetics in seaborn, but let's now go over it formally:

# %% [markdown]
# ## Styles
#
# You can set particular styles:

# %%
sns.countplot(data= tips, x = 'sex')

# %%
# seaborne has a set style arguments which allows to set the style for the rest of the plots.

#sns.set_style('darkgrid')
#sns.set_style('whitegrid')
#sns.set_style('white')
sns.set_style('ticks')

sns.countplot(data= tips, x = 'sex')

# %% [markdown]
# ## Spine Removal

# %%
sns.countplot(data= tips, x = 'sex')

# another thing you can do is remove spines.
sns.despine()

# by default top and right are true to be removed left and bottom or not to be removed.
#sns.despine(left = True, bottom = True)

# %% [markdown]
# ## Size and Aspect
#
# You can use matplotlib's **plt.figure(figsize=(width,height) ** to change the size of most seaborn plots.
#
# You can control the size and aspect ratio of most seaborn grid plots by passing in parameters: size, and aspect. For example:

# %%
# size and aspect.
# You can use matplotlib  plt.figure(figsize = width, height) to actually change the size of most Seaborn blocks.
# and also control the size and aspect ratio of a seaborn grid plots by passing in the parameters size and aspect.
# Matplotlib will actually set the figure size for the Seaborn plot.
# So you can use Matplotlib knowledge as far as figure sizing and aspect ratios here in combination with seaborn.

plt.figure(figsize=(12,3))
sns.countplot(data= tips, x = 'sex')

# %% [markdown]
# ## Scale and Context
#
# The set_context() allows you to override default parameters:

# %%
""" Now let's go ahead and touch on the topic of scale and context.
SEABORN comes of a convenient set_context which allows you to over id default parameters and
change font scales depending on what you're actually creating the figure for.

So let's say you are going to create this figure not for a notebook but actually for a poster. """


sns.set_context('poster')
sns.countplot(data= tips, x = 'sex')

# %%
sns.set_context('poster', font_scale=0.5)
sns.countplot(data= tips, x = 'sex')

# %%
# usually by default it's going to be in the context of a notebook.

sns.set_context('notebook')
sns.countplot(data= tips, x = 'sex')

# %%
# palettes and colors.

sns.lmplot(x= 'total_bill', y = 'tip', data = tips, hue = 'sex')

# %%
# change colors? we can actually pass in a Palette arguments and there are certain strings
# that essentially gives a color map like magma or cool warm.

sns.lmplot(x= 'total_bill', y = 'tip', data = tips, hue = 'sex', palette= 'coolwarm')

# %%
# Now you may be wondering what we're you actually find these strings.
# Well you can find them by going to map plot lives color map page. Go to google!
# https://matplotlib.org/stable/users/explain/colors/colormaps.html

sns.lmplot(x= 'total_bill', y = 'tip', data = tips, hue = 'sex', palette= 'seismic')

# %% [markdown]
# Check out the documentation page for more info on these topics:
# https://stanford.edu/~mwaskom/software/seaborn/tutorial/aesthetics.html

# %% [markdown]
# /Users/marci/anaconda/lib/python3.5/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %% [markdown]
# ## Exercises
